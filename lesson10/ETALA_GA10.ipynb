# %%
load('../etala_utilities.sage')

# %% [markdown]
# ### ETALA lesson 10
# # Group Assignment
# Problems:
# __6.1:__ 1, 13, 16, 19, 26, 30
# __6.2:__ 1, 4, 7, 12, 13, 21, 35
# __6.3:__ 1, 7, 13, 17, 21

# %% [markdown]
# ## Chapter 6.1

# %% [markdown]
# ### Problem 1
# ![image.png](attachment:image.png)

# %%
# %display latex 
u = vector([-1, 2])
v = vector([4, 6])
w = vector([3, -1, -5])
x = vector([6, -2, 3])
uu = u.dot_product(u)
show(f'u dot u = {uu}')
vu = v.dot_product(u)
show(f'v dot u = {vu}')
vu_norm = v.dot_product(u)/u.dot_product(u)
show(f'v dot u / u dot u = {vu_norm}')
# Out:
# 'u dot u = 5'
# 'v dot u = 8'
# 'v dot u / u dot u = 8/5'

# %% [markdown]
# ### Problem 13
# ![image.png](attachment:image.png)

# %%
x = vector([10, -3])
y = vector([-1, -5])
f'dist(x, y) = {(x-y).norm()}'
# Out:
# 'dist(x, y) = 5*sqrt(5)'

# %% [markdown]
# ### Problem 16
# ![image.png](attachment:image.png)

# %%
u = vector([12, 3, -5])
v = vector([2, -3, 3])
show(f'u and v are othagonal: {u.dot_product(v) == 0}')
# Out:
# 'u and v are othagonal: True'

# %% [markdown]
# ### Problem 19
# ![image.png](attachment:image.png)

# %% [markdown]
# a): True since $\| \boldsymbol v \| = \sqrt{\boldsymbol v \cdot \boldsymbol v}$
# b): True
# c): True
# d): False, The orthagonal complement to the _row_ space of A is the null space of A
# e): True, that is the definition of $W^\bot$

# %% [markdown]
# ### Problem 26
# ![image.png](attachment:image.png)

# %% [markdown]
# Theroem 4.2 shows that $W$ is a subspace of $\Bbb R^3$, since it forms the null space of the 1x3 vector $\boldsymbol u^T$.
# Since the null space is orthogonal to the rows of $\boldsymbol u^T$ being the single column of $\boldsymbol u$, $W$ must be a plane in $\Bbb R^3$.

# %% [markdown]
# ### Problem 30
# ![image.png](attachment:image.png)
