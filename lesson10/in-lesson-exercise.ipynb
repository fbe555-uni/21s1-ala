# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
R_1 = 4.7*10^3
R_2 = 22*10^3
C_1 = 1*10^-6
C_2 = 47*10^-9
A = Matrix([[-(1/C_1)*(1/R_1 + 1/R_2), 1/(R_2*C_1)], [1/(R_2*C_2), -1/(R_2*C_2)]])
show('A = ', A)
# Out:
# 'A = ' [-258.220502901354  45.4545454545455]
# [ 967.117988394584 -967.117988394584]

# %%
show('det(A) = ', A.determinant())
# Out:
# 'det(A) = ' 205769.784764805

# %%
var('l')
res = solve((A-l*Matrix.identity(2,2)).determinant(), l)
l_1 =
# Out:
# [l == -250/517*sqrt(725289) - 316750/517, l == 250/517*sqrt(725289) - 316750/517]

# %%
solve
